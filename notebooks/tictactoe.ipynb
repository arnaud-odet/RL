# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from rl_lib.tictactoe.agents import train_agents 
# %reload_ext autoreload
# %autoreload 2

# %%
train_agents(episodes = 20,
             agent1_eps=0.1,
             agent2_eps=0.1,
             epsilon_decay=0.998,
             min_epsilon=0.05)
# Out:
# Training in progress : game 20/20, epsilon : agent1 = 0.0937, agent2 = 0.0887, P2 started
# Playing a demonstration game with trained agents...
#
# Demonstration game between trained agents:
# Initial board:
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
#
# Player 1 (X) moves to position (np.int64(2), np.int64(1))
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# |   | X |   |
# -------------
#
# Player 2 (O) moves to position (np.int64(0), np.int64(1))
# -------------
# |   | O |   |
# -------------
# |   |   |   |
# -------------
# |   | X |   |
# -------------
#
# Player 1 (X) moves to position (np.int64(0), np.int64(0))
# -------------
# | X | O |   |
# -------------
# |   |   |   |
# -------------
# |   | X |   |
# -------------
#
# Player 2 (O) moves to position (2, 0)
# -------------
# | X | O |   |
# -------------
# |   |   |   |
# -------------
# | O | X |   |
# -------------
#
# ...
